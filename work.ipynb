# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_csv("student_habits_performance.csv")

# %%
data.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
data[data["gender"]=="Female"].count()
# Out:
# student_id                       481
# age                              481
# gender                           481
# study_hours_per_day              481
# social_media_hours               481
# netflix_hours                    481
# part_time_job                    481
# attendance_percentage            481
# sleep_hours                      481
# diet_quality                     481
# exercise_frequency               481
# parental_education_level         433
# internet_quality                 481
# mental_health_rating             481
# extracurricular_participation    481
# exam_score                       481
# dtype: int64

# %%
data["age"].mean()
# Out:
# np.float64(20.498)

# %%
data["study_hours_per_day"].median()
# Out:
# np.float64(3.5)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
# ...

# %%
data.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
data.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe(include="object")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12944\460854327.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include="object")
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
# ...

# %%
data[data["gender"]!="Male" ]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# 6        S1006   21  Female                  5.6                 1.5
# ..         ...  ...     ...                  ...                 ...
# 987      S1987   20  Female                  2.3                 1.6
# 994      S1994   20  Female                  1.6                 1.3
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
data["gender"].info()
# Out:
# <class 'pandas.Series'>
# Index: 909 entries, 0 to 999
# Series name: gender
# Non-Null Count  Dtype
# --------------  -----
# 909 non-null    str
# dtypes: str(1)
# memory usage: 14.2 KB

# %%
data["gender"].unique()
# Out:
# <StringArray>
# ['Female', 'Male', 'Other']
# Length: 3, dtype: str

# %%
data["gender"].value_counts()
# Out:
# gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 909 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     909 non-null    str
#  1   age                            909 non-null    int64
#  2   gender                         909 non-null    str
#  3   study_hours_per_day            909 non-null    float64
#  4   social_media_hours             909 non-null    float64
#  5   netflix_hours                  909 non-null    float64
#  6   part_time_job                  909 non-null    str
#  7   attendance_percentage          909 non-null    float64
#  8   sleep_hours                    909 non-null    float64
#  9   diet_quality                   909 non-null    str
#  10  exercise_frequency             909 non-null    int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               909 non-null    str
# ...

# %%
categorical_cols=["gender","part_time_job","diet_quality","parental_education_level","internet_quality","extracurricular_participation"]

# %%
categorical_cols
# Out:
# ['gender',
#  'part_time_job',
#  'diet_quality',
#  'parental_education_level',
#  'internet_quality',
#  'extracurricular_participation']

# %%
for col in categorical_cols:
    print(f"Values count for {col} :\n {data[col].value_counts()}")
    print()
# Out:
# Values count for gender :
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
#
# Values count for part_time_job :
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
#
# Values count for diet_quality :
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
#
# Values count for parental_education_level :
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
#
# Values count for internet_quality :
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
#
# Values count for extracurricular_participation :
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
data.hist(bins=20,edgecolor="black")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
for col in categorical_cols:
    sns.countplot(data=data,x=col)# Setting Counterplot
    plt.title(f"Distribution of {col}")#Setting title for each plot
    plt.yticks(range(0, 901,150))
    plt.xticks(rotation=45)# rotate the name of clm to reduce overlapping
    plt.show()

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix : ")
plt.show()

# %%
data.describe().columns #describes()- it describes numerical columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='str')

# %%
num_feature=['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for f in num_feature:
    sns.scatterplot(data=data,x=f,y="exam_score")
    plt.title(f"{f} Vs Exam Score")
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(data=data,x=col,y="exam_score")
    plt.title(f"{col} vs exam score")
    plt.show()

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
data.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='str')

# %%
features=['study_hours_per_day','attendance_percentage','sleep_hours','part_time_job','mental_health_rating']

# %%
target="exam_score"

# %%
data_model=data[features+[target]].copy()

# %%
data_model.head()
# Out:
#    study_hours_per_day  attendance_percentage  sleep_hours part_time_job  \
# 0                  0.0                   85.0          8.0            No
# 1                  6.9                   97.3          4.6            No
# 2                  1.4                   94.8          8.0            No
# 3                  1.0                   71.0          9.2            No
# 4                  5.0                   90.9          4.9            No
#
#    mental_health_rating  exam_score
# 0                     8        56.2
# 1                     8       100.0
# 2                     1        34.3
# 3                     1        26.8
# 4                     1        66.4

# %%
#to convert the stringinto numeric form
le=LabelEncoder()
data_model["part_time_job"]=le.fit_transform(data_model["part_time_job"])

# %%
data_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  part_time_job  \
# 0                    0.0                   85.0          8.0              0
# 1                    6.9                   97.3          4.6              0
# 2                    1.4                   94.8          8.0              0
# 3                    1.0                   71.0          9.2              0
# 4                    5.0                   90.9          4.9              0
# ..                   ...                    ...          ...            ...
# 995                  2.6                   77.0          7.5              0
# 996                  2.9                   86.0          6.8              1
# 997                  3.0                   61.9          6.5              0
# 998                  5.4                  100.0          7.6              1
# 999                  4.3                   89.4          7.1              0
#
#      mental_health_rating  exam_score
# ...

# %%
X =data_model[features]
X
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  part_time_job  \
# 0                    0.0                   85.0          8.0              0
# 1                    6.9                   97.3          4.6              0
# 2                    1.4                   94.8          8.0              0
# 3                    1.0                   71.0          9.2              0
# 4                    5.0                   90.9          4.9              0
# ..                   ...                    ...          ...            ...
# 995                  2.6                   77.0          7.5              0
# 996                  2.9                   86.0          6.8              1
# 997                  3.0                   61.9          6.5              0
# 998                  5.4                  100.0          7.6              1
# 999                  4.3                   89.4          7.1              0
#
#      mental_health_rating
# 0                       8
# ...

# %%
y=data_model[target]
y
# Out:
# 0       56.2
# 1      100.0
# 2       34.3
# 3       26.8
# 4       66.4
#        ...
# 995     76.1
# 996     65.9
# 997     64.4
# 998     69.7
# 999     74.9
# Name: exam_score, Length: 909, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models=models = {
    "LinearRegression": {
        "model": LinearRegression(),
        "params": {}
    },
    
    "DecisionTree": {
        "model": DecisionTreeRegressor(),
        "params": {
            "max_depth": [3, 5, 10],
            "min_samples_split": [2, 5]
        }
    },
    
    "RandomForest": {
        "model": RandomForestRegressor(),
        "params": {
            "n_estimators": [50, 100],
            "max_depth": [5, 10]
        }
    }
}

# %%
best_models=[]

# %%
for name, config in models.items():
    print(f"Training {name}")

    grid = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
    grid.fit(X_train, y_train)

    y_pred = grid.predict(X_test)

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_models.append({
        "model": name,
        "best_params": grid.best_params_,
        "rmse": rmse,
        "r2": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
result_data=pd.DataFrame(best_models)

# %%
result_data.sort_values(by="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  6.913160
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  6.955496
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  7.600401
#
#          r2
# 0  0.822251
# 2  0.820067
# 1  0.785154

# %%
import joblib

# %%
best_row=result_data.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                    6.91316
# r2                     0.822251
# Name: 0, dtype: object

# %%
best_model_name=best_row["model"]
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config=models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model=best_model_config["model"]

# %%
final_model
# Out:
# LinearRegression()

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model,"best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 66.18579405,  98.26310392,  83.07636937,  63.02878767,
#         71.10976502,  75.00352966,  66.71216009,  80.25838196,
#         68.31359587,  55.7323605 ,  39.79507284,  57.98249864,
#         85.07548216,  57.63384029,  68.30053395,  73.17116424,
#         89.8219083 ,  71.53075848, 104.70803339,  57.380995  ,
#         67.76353877,  65.68154311,  72.88151862,  94.31676369,
#         77.28506823,  57.44126378,  66.64007487,  68.45406642,
#         61.88623029,  60.98129875,  74.18329974,  71.00132175,
#         47.74082004,  83.39081928,  69.58524171,  49.45186634,
#         48.86907863,  47.17047877, 111.48229376,  70.56670815,
#         47.21912588,  74.79642259,  70.20854282,  68.93258247,
#         58.99100986,  63.72550851,  47.52966995,  70.61496485,
#         46.42355805,  82.51642869,  54.84649087,  74.44479129,
#         69.31005922,  63.64137371,  63.24170396,  58.28779096,
#         81.1148883 , 100.28724338,  55.87543662,  72.22004207,
# ...
